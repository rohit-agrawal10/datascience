# %% [markdown]
# ## Final Project

# %% [markdown]
# ## Rohit - From Question26

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import display

matplotlib.rc("figure", figsize=(8,6))
matplotlib.rc("axes", labelsize=16, titlesize=16)
matplotlib.rc("xtick", labelsize=14)
matplotlib.rc("ytick", labelsize=14)
matplotlib.rc("legend", fontsize=14)
matplotlib.rc("font", size=14)

df1 = pd.read_excel('DDS9_Data_Extract_with_labels.xlsx')
df2 = pd.read_excel('DDS10_Data_Extract_with_labels.xlsx')
df3 = pd.read_excel('DDS11_Data_Extract_with_labels.xlsx')

# %% [markdown]
# ## Nature of Subscription Services

# %%
old_label =[]
new_label =[]
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Pay TV (cable and/or satellite)")
new_label.append("Pay TV")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Home internet")
new_label.append("Home internet")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Landline telephone")
new_label.append("Landline Telephone")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Mobile voice (smartphone or basic mobile phone calling plan)")
new_label.append("Mobile voice")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Streaming video service")
new_label.append("Streaming video service")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Streaming music service")
new_label.append("Streaming music service")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Gaming")
new_label.append("Gaming")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-News/Newspaper (print or digital)")
new_label.append("News")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-Magazine (print or digital)")
new_label.append("Magazine")
old_label.append("Q26 - Which of the following subscriptions does your household purchase?-None of the above")
new_label.append("None")

# %%
for i in range(0, len(old_label)):
    df1.rename(columns={old_label[i] : new_label[i]}, inplace=True)
    df2.rename(columns={old_label[i] : new_label[i]}, inplace=True)
    df3.rename(columns={old_label[i] : new_label[i]}, inplace=True)

# %%
for i in range(1, len(new_label)):
    df1[new_label[i]].replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
for i in range(1, len(new_label)):
    df2[new_label[i]].replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
df_heatmap = df1[new_label]
corr = df_heatmap.corr()
plt.clf()
sns.heatmap(corr)
plt.show()

# %% [markdown]
# ###### High Correlations between News and Magazine, Streaming Video and Streaming Audio Services

# %%
subscription_2010= {}
subscription_2011= {}
for label in new_label:
    subscription_2010[label] = df1[label].sum()
    subscription_2011[label] = df2[label].sum()

# %%
# data to plot
n_groups = len(new_label)
val_2010 = subscription_2010.values()
val_2011 = subscription_2011.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')
 
rects2 = plt.bar(index + bar_width, val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
plt.xlabel('Count of subscribers')
plt.ylabel('Subscription type')
plt.title(' Count of subscribers by year')
plt.xticks(index + bar_width, subscription_2010.keys(), rotation = 90)
plt.legend()
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Home Internet has the highest subscribers. Streaming Video and Audio subscriptions are on the rise

# %% [markdown]
# ## Valuation of Subscription Services

# %%
old_label =[]
new_label =[]

old_label.append("Q36r1 - Pay TV (cable and/or satellite) - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking each item in the o")
old_label.append("Q36r2 - Home internet - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking each item in the order you wish to r")
old_label.append("Q36r3 - Landline telephone - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking each item in the order you wish")
old_label.append("Q36r4 - Mobile voice - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking each item in the order you wish to ra")
old_label.append("Q36r6 - Streaming video service  - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selec")
old_label.append("Q36r7 - Streaming music service  - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking e")
old_label.append("Q36r8 - Gaming - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicki")
old_label.append("Q36r9 - News/Newspaper (print or digital) - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking each item in the")
old_label.append("Q36r10 - Magazine (print or digital) - Of the services you indicated your household purchases, which [totalcount] do you value the most?Please rank the top [totalcount], with \"1\" being the most valued. Make your selections by clicking each item in the orde")

new_label.append("VPay TV")
new_label.append("VHome internet")
new_label.append("VLandline Telephone")
new_label.append("VMobile voice")
new_label.append("VStreaming video service")
new_label.append("VStreaming music service")
new_label.append("VGaming")
new_label.append("VNews")
new_label.append("VMagazine")

# %%
for i in range(0, len(old_label)):
    df1.rename(columns={old_label[i] : new_label[i]}, inplace=True)
    df2.rename(columns={old_label[i] : new_label[i]}, inplace=True)
    df3.rename(columns={old_label[i] : new_label[i]}, inplace=True)

# %%
for i in range(0, len(new_label)):
    df1[new_label[i]].fillna(4, inplace = True)

# %%
subscription_2010= {}
for label in new_label:
    subscription_2010[label] = df1[label].sum()

# %%
ticks = []
ticks.append("Pay TV")
ticks.append("Home internet")
ticks.append("Landline Telephone")
ticks.append("Mobile voice")
ticks.append("Streaming video service")
ticks.append("Streaming music service")
ticks.append("Gaming")
ticks.append("News")
ticks.append("Magazine")

plt.bar(range(len(subscription_2010)), subscription_2010.values(), align='center')
plt.xticks(range(len(subscription_2010)), ticks, rotation = 90)

plt.show()

# %% [markdown]
# ###### Note in this graph lower is better. Top 3 most valuable subscriptions in order :
#
# * Home Internet
# * Landline Telephone
# * Streaming Video Service

# %% [markdown]
# ## Movie Consumption

# %%
old_label = []
new_label = []
old_label.append("QNEW19r1 - Rent a physical DVD/Blu-ray - Thinking about how you watch movies, how frequently do you do each of the following?")
old_label.append("QNEW19r2 - Purchase a physical DVD/Blu-ray - Thinking about how you watch movies, how frequently do you do each of the following?")
old_label.append("QNEW19r3 - Purchase digital video entertainment to download onto your device via online service - Thinking about how you watch movies, how frequently do you do each of the following?")
old_label.append("QNEW19r4 - Rent digital video entertainment where a digital file is downloaded to your device - Thinking about how you watch movies, how frequently do you do each of the following?")
old_label.append("QNEW19r5 - Watch digital video entertainment via an online streaming service  - Thinking about how you watch movies, how frequently do you do each of the following?")
old_label.append("QNEW19r6 - Purchase/rent a video via your television service provider's On-Demand or Pay-Per-View service (i.e., via a set-top-box) - Thinking about how you watch movies, how frequently do you do each of the following?")

new_label.append("Rent DVD")
new_label.append("Purchase DVD")
new_label.append("Purchase Digital Video")
new_label.append("Rent Digital Video")
new_label.append("Online Streaming")
new_label.append("TV On-Demand")

# %%
for i in range(0, len(old_label)):
    df1.rename(columns={old_label[i] : new_label[i]}, inplace=True)

# %%
d = {}
d['Never'] = 0
d['Rarely (one to three times a year)'] = 1
d['Occasionally (monthly)'] = 2
d['Frequently (every day/weekly)'] = 3

# %%
for label in new_label:
    df1[label].replace(d, inplace=True)

# %%
video_consumption= {}
for label in new_label:
    video_consumption[label] = df1[label].sum()

# %%
plt.bar(range(len(video_consumption)), video_consumption.values(), align='center')
plt.xticks(range(len(video_consumption)), video_consumption.keys(), rotation = 90)

plt.show()

# %% [markdown]
# ###### Top choices of movie consumption in order of usage:
#
# * Online Streaming
# * Rent DVD
# * Purchase DVD
# * TV On-Demand

# %%
old_label = []
new_label = []
old_label.append("QNEW20r1 - Rent a physical DVD/Blu-ray - Thinking about how you watch television programming, how frequently do you do each of the following?")
old_label.append("QNEW20r2 - Purchase a physical DVD/Blu-ray - Thinking about how you watch television programming, how frequently do you do each of the following?")
old_label.append("QNEW20r3 - Purchase digital video entertainment to download onto your device via online service - Thinking about how you watch television programming, how frequently do you do each of the following?")
old_label.append("QNEW20r4 - Watch digital video entertainment via an online streaming service  - Thinking about how you watch television programming, how frequently do you do each of the following?")
old_label.append("QNEW20r5 - Purchase/rent a video via your television service provider's On-Demand or Pay-Per-View service (i.e., via a set-top-box) - Thinking about how you watch television programming, how frequently do you do each of the following?")

new_label.append("TVRent DVD")
new_label.append("TVPurchase DVD")
new_label.append("TVPurchase Digital Video")
new_label.append("TVOnline Streaming")
new_label.append("TVTV On-Demand")

# %%
for i in range(0, len(old_label)):
    df1.rename(columns={old_label[i] : new_label[i]}, inplace=True)
for label in new_label:
    df1[label].replace(d, inplace=True)

# %%
tv_consumption= {}
for label in new_label:
    tv_consumption[label] = df1[label].sum()

# %%
ticks =[]
ticks.append("Rent DVD")
ticks.append("Purchase DVD")
ticks.append("Purchase Digital Video")
ticks.append("Online Streaming")
ticks.append("TV On-Demand")
plt.bar(range(len(tv_consumption)), tv_consumption.values(), align='center')
plt.xticks(range(len(tv_consumption)), ticks, rotation = 90)

plt.show()

# %% [markdown]
# ###### Top choices of Television consumption in order of usage:
#
# * Rent DVD
# * TV On-Demand

# %% [markdown]
# ## Binge Watching TV Series

# %%
old_label = "QNEW24 - Do you ever \"binge-watch\" television shows, meaning watching three or more episodes of a TV series in one sitting?"
new_label = "Binge Watch"
df1.rename(columns={old_label : new_label}, inplace=True)
df2.rename(columns={old_label : new_label}, inplace=True)
df3.rename(columns={old_label : new_label}, inplace=True)

# %%
df1[new_label].replace(('Yes', 'No'), (1, 0), inplace=True)
df2[new_label].replace(('Yes', 'No'), (1, 0), inplace=True)
df3[new_label].replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
# data to plot
bw_2010 = {}
bw_2011 = {}
bw_2012 = {}

n_groups = 1
bw_2010['Yes'] = float(100 * df1[new_label].sum()) / float(len(df1))
bw_2011['Yes'] = float(100 * df2[new_label].sum()) / float(len(df2))
bw_2012['Yes'] = float(100 * df3[new_label].sum()) / float(len(df3))

val_2010 = bw_2010.values()
val_2011 = bw_2011.values()
val_2012 = bw_2012.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.05
opacity = 0.8
 
rects1 = plt.bar(index, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')
 
rects2 = plt.bar(index + bar_width, val_2011, bar_width,
                 alpha=opacity,
                 label='2011')

rects3 = plt.bar(index + (2*bar_width), val_2012, bar_width,
                 alpha=opacity,
                 label='2012')
 
plt.ylabel('Percentage of Binge Watchers')
plt.title('Percentage of binge watchers by year')
plt.xticks(index + bar_width, bw_2010.keys())
plt.legend()
 

plt.show()

# %% [markdown]
# ##### Hence, we can see we have around 65-70% responses who binge watch shows. This is significant
