# %% [markdown]
# ## Final Project

# %% [markdown]
# ## Rohit - From Question26

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import display
import collections
from math import isnan
from numpy import nan
matplotlib.rc("figure", figsize=(8,6))
matplotlib.rc("axes", labelsize=16, titlesize=16)
matplotlib.rc("xtick", labelsize=14)
matplotlib.rc("ytick", labelsize=14)
matplotlib.rc("legend", fontsize=14)
matplotlib.rc("font", size=14)

df1 = pd.read_excel('../DDS9_Data_Extract_with_labels.xlsx')
df2 = pd.read_excel('../DDS10_Data_Extract_with_labels.xlsx')
df3 = pd.read_excel('../DDS11_Data_Extract_with_labels.xlsx')

# %% [markdown]
# ## Nature of Subscription Services

# %%
new_label = []
new_label.append("Pay TV")
new_label.append("Home internet")
new_label.append("Landline telephone")
new_label.append("Mobile voice")
new_label.append("Mobile data plan")
new_label.append("Streaming video service")
new_label.append("Streaming music service")
new_label.append("Gaming")
new_label.append("News")
new_label.append("Magazine")
new_label.append("None")

# %%
for i in range(0, len(new_label)):
    df1[new_label[i]].replace(('Yes', 'No'), (1, 0), inplace=True)
    df2[new_label[i]].replace(('Yes', 'No'), (1, 0), inplace=True)
    df3[new_label[i]].replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
df_heatmap = df1[new_label]
corr = df_heatmap.corr()
plt.clf()
sns.heatmap(corr)
plt.show()

# %% [markdown]
# ###### High Correlations between News and Magazine, Streaming Video and Streaming Audio Services

# %%
subscription_2009= {}
subscription_2010= {}
subscription_2011= {}
for label in new_label:
    subscription_2009[label] = df1[label].sum()
    subscription_2010[label] = df2[label].sum()
    subscription_2011[label] = df3[label].sum()

# %%
# data to plot
n_groups = len(new_label)
val_2009 = subscription_2009.values()
val_2010 = subscription_2010.values()
val_2011 = subscription_2011.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Count of subscribers')
plt.xlabel('Subscription type')
plt.title(' Count of subscribers by year')
plt.xticks(index + (bar_width), subscription_2010.keys(), rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# ##### Home Internet has the highest subscribers. Streaming Video and Audio subscriptions and Gaming are on the rise

# %% [markdown]
# ## Valuation of Subscription Services

# %%
new_label =[]

new_label.append("VPay TV")
new_label.append("VHome internet")
new_label.append("VLandline telephone")
new_label.append("VMobile voice")
new_label.append("VMobile data plan")
new_label.append("VStreaming video service")
new_label.append("VStreaming music service")
new_label.append("VGaming")
new_label.append("VNews")
new_label.append("VMagazine")

# %%
for i in range(0, len(new_label)):
    df1[new_label[i]].fillna(4, inplace = True)
    df2[new_label[i]].fillna(4, inplace = True)
    df3[new_label[i]].fillna(4, inplace = True)

# %%
subscription_2009= {}
subscription_2010= {}
subscription_2011= {}
for label in new_label:
    subscription_2009[label] = df1[label].sum()
    subscription_2010[label] = df2[label].sum()
    subscription_2011[label] = df3[label].sum()

# %%
ticks = []

ticks.append("Pay TV")
ticks.append("Home internet")
ticks.append("Landline telephone")
ticks.append("Mobile voice")
ticks.append("Mobile data plan")
ticks.append("Streaming video service")
ticks.append("Streaming music service")
ticks.append("Gaming")
ticks.append("News")
ticks.append("Magazine")


matplotlib.rc("figure", figsize=(10,6))
matplotlib.rc("axes", labelsize=16, titlesize=16)
matplotlib.rc("xtick", labelsize=14)
matplotlib.rc("ytick", labelsize=14)
matplotlib.rc("legend", fontsize=14)
matplotlib.rc("font", size=14)

# data to plot
n_groups = len(new_label)
val_2009 = subscription_2009.values()
val_2010 = subscription_2010.values()
val_2011 = subscription_2011.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Value (Lower is more valuable)')
plt.xlabel('Subscription type')
plt.title('Value of subscription by year')
plt.xticks(index + (bar_width), ticks, rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# ###### Note in this graph lower is better. Top 3 most valuable subscriptions in order :
#
# * Home Internet
# * Landline Telephone
# * Gaming
#
# ##### What's least valuable :
# * Pay TV

# %% [markdown]
# ## Movie Consumption

# %%
new_label = []

new_label.append("Movie - Rent DVD")
new_label.append("Movie - Purchase DVD")
new_label.append("Movie - Purchase Digital Video")
new_label.append("Movie - Rent Digital Video")
new_label.append("Movie - Online Streaming")
new_label.append("Movie - TV On-Demand")

# %%
d = {}
d['Never'] = 0
d['Rarely (one to three times a year)'] = 1
d['Occasionally (monthly)'] = 4
d['Frequently (every day/weekly)'] = 16

# %%
for label in new_label:
    print label
    df1[label] = df1[label].map(d)
    df2[label] = df2[label].map(d)
    df3[label] = df3[label].map(d)
# Out:
# Movie - Rent DVD
# Movie - Purchase DVD
# Movie - Purchase Digital Video
# Movie - Rent Digital Video
# Movie - Online Streaming
# Movie - TV On-Demand

# %%
consumption_2009= {}
consumption_2010= {}
consumption_2011= {}
for label in new_label:
    consumption_2009[label] = df1[label].sum()
    consumption_2010[label] = df2[label].sum()
    consumption_2011[label] = df3[label].sum()

# %%
ticks = []

ticks.append("Rent DVD")
ticks.append("Purchase DVD")
ticks.append("Purchase Digital Video")
ticks.append("Rent Digital Video")
ticks.append("Online Streaming")
ticks.append("TV On-Demand")

matplotlib.rc("figure", figsize=(10,6))
matplotlib.rc("axes", labelsize=16, titlesize=16)
matplotlib.rc("xtick", labelsize=14)
matplotlib.rc("ytick", labelsize=14)
matplotlib.rc("legend", fontsize=14)
matplotlib.rc("font", size=14)

# data to plot
n_groups = len(new_label)
val_2009 = consumption_2009.values()
val_2010 = consumption_2010.values()
val_2011 = consumption_2011.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Cumulative Frequency of consumption')
plt.xlabel('Consumption type')
plt.title('Consumption pattern of movie by year')
plt.xticks(index + (bar_width), ticks, rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# ###### Top choices of movie consumption in order of usage:
#
# * Purchase Diit
# * Rent DVD
# * Purchase DVD
# * TV On-Demand
#
# ##### What's on the rise ?
# * Online Streaming
# * TV On-Demand
# * Rent Digital Video

# %% [markdown]
# ### TV Program Consumption

# %%
new_label = []

new_label.append("TV Series - Rent DVD")
new_label.append("TV Series - Purchase DVD")
new_label.append("TV Series - Purchase Digital Video")
new_label.append("TV Series - Online Streaming")
new_label.append("TV Series - TV On-Demand")

# %%
for label in new_label:
    print label
    df1[label] = df1[label].map(d)
    df2[label] = df2[label].map(d)
    df3[label] = df3[label].map(d)
# Out:
# TV Series - Rent DVD
# TV Series - Purchase DVD
# TV Series - Purchase Digital Video
# TV Series - Online Streaming
# TV Series - TV On-Demand

# %%
consumption_2009= {}
consumption_2010= {}
consumption_2011= {}
for label in new_label:
    consumption_2009[label] = df1[label].sum()
    consumption_2010[label] = df2[label].sum()
    consumption_2011[label] = df3[label].sum()

# %%
ticks = []

ticks.append("Rent DVD")
ticks.append("Purchase DVD")
ticks.append("Purchase Digital Video")
ticks.append("Online Streaming")
ticks.append("TV On-Demand")

matplotlib.rc("figure", figsize=(10,6))
matplotlib.rc("axes", labelsize=16, titlesize=16)
matplotlib.rc("xtick", labelsize=14)
matplotlib.rc("ytick", labelsize=14)
matplotlib.rc("legend", fontsize=14)
matplotlib.rc("font", size=14)

# data to plot
n_groups = len(new_label)
val_2009 = consumption_2009.values()
val_2010 = consumption_2010.values()
val_2011 = consumption_2011.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Cumulative Frequency of consumption')
plt.xlabel('Consumption type')
plt.title('Consumption Pattern of TV by year')
plt.xticks(index + (bar_width), ticks, rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# ###### Top choices of Television consumption in order of usage:
#
# * Online Streaming and on the rise

# %% [markdown]
# ## Binge Watching TV Series

# %%
old_label = "QNEW24 - Do you ever \"binge-watch\" television shows, meaning watching three or more episodes of a TV series in one sitting?"
new_label = "Binge Watch"
df1.rename(columns={old_label : new_label}, inplace=True)
df2.rename(columns={old_label : new_label}, inplace=True)
df3.rename(columns={old_label : new_label}, inplace=True)

# %%
df1[new_label].replace(('Yes', 'No'), (1, 0), inplace=True)
df2[new_label].replace(('Yes', 'No'), (1, 0), inplace=True)
df3[new_label].replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
# data to plot
bw_2010 = {}
bw_2011 = {}
bw_2012 = {}

n_groups = 1
bw_2010['Yes'] = float(100 * df1[new_label].sum()) / float(len(df1))
bw_2011['Yes'] = float(100 * df2[new_label].sum()) / float(len(df2))
bw_2012['Yes'] = float(100 * df3[new_label].sum()) / float(len(df3))

val_2010 = bw_2010.values()
val_2011 = bw_2011.values()
val_2012 = bw_2012.values()
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.05
opacity = 0.8
 
rects1 = plt.bar(index, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')
 
rects2 = plt.bar(index + bar_width, val_2011, bar_width,
                 alpha=opacity,
                 label='2011')

rects3 = plt.bar(index + (2*bar_width), val_2012, bar_width,
                 alpha=opacity,
                 label='2012')
 
plt.ylabel('Percentage of Binge Watchers')
plt.title('Percentage of binge watchers by year')
plt.xticks(index + bar_width, bw_2010.keys())
plt.legend()
 

plt.show()

# %% [markdown]
# ##### Hence, we can see we have around 65-70% responses who binge watch shows. This is significant

# %%
new_label = []
new_label.append("TV Series - Rent DVD")
new_label.append("TV Series - Purchase DVD")
new_label.append("TV Series - Purchase Digital Video")
new_label.append("TV Series - Online Streaming")
new_label.append("TV Series - TV On-Demand")
new_label.append("Binge Watch")

df_heatmap = df1[new_label]
corr = df_heatmap.corr()
corr = corr[['Binge Watch']]
plt.clf()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ### Binge watchers use Online Streaming as their preferred mode

# %% [markdown]
# ## News Source

# %%
news = {}
news['Television news stations'] = 1
news['Variety/talk shows'] = 2
news['Radio']= 3
news['Print newspapers']= 4
news['Online version of newspapers']= 5
news['News aggregators']= 6
news['Online news sites not associated with a newspaper'] = 7
news['Social media sites']= 8
news['Magazine']= 9
news['I do not follow the news']= 10

label = 'News Source'

# %%
news_2009 = dict(collections.Counter(df1[label]))
news_2010 = dict(collections.Counter(df2[label]))
news_2011 = dict(collections.Counter(df3[label]))
news_2009['Magazine']= 0

# %%
ticks = []
ticks.append('Online Newspapers')
ticks.append('Magazine')
ticks.append('No News')
ticks.append('Print Newspapers')
ticks.append('Talk shows')
ticks.append('News Aggregators')
ticks.append('Television News Stations')
ticks.append('Online Independent News')
ticks.append('Radio')
ticks.append('Social media')




# data to plot
n_groups = len(news)
val_2009 = []
val_2010 = []
val_2011 = []

for label in news.keys():
    val_2009.append(news_2009[label])
    val_2010.append(news_2010[label])
    if label == 'Online news sites not associated with a newspaper':
        val_2011.append(news_2011['Online news sites not associated with a traditional news organization'])
    else:
        val_2011.append(news_2011[label])

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Cumulative consumption')
plt.xlabel('News Sources')
plt.title('Consumption of News sources by year')
plt.xticks(index + (bar_width), ticks, rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# ##### TV News stations still popular but declining. Social Media showing highest growth

# %% [markdown]
# ## Entertainment Sources

# %%
new_label =[]
new_label.append("Entertainment - Live Performance")
new_label.append("Entertainment - Movies")
new_label.append("Entertainment - Television")
new_label.append("Entertainment - Music")
new_label.append("Entertainment - Books")
new_label.append("Entertainment - Magazines")
new_label.append("Entertainment - Newspapers")
new_label.append("Entertainment - Radio")
new_label.append("Entertainment - Gaming")
new_label.append("Entertainment - Internet")

# %%
for i in range(0, len(new_label)):
    df1[new_label[i]].fillna(4, inplace = True)
    df2[new_label[i]].fillna(4, inplace = True)
    df3[new_label[i]].fillna(4, inplace = True)

# %%
entertainment_2009= {}
entertainment_2010= {}
entertainment_2011= {}
for label in new_label:
    entertainment_2009[label] = df1[label].sum()
    entertainment_2010[label] = df2[label].sum()
    entertainment_2011[label] = df3[label].sum()

# %%
ticks = []

ticks.append("Live Performance")
ticks.append("Movies")
ticks.append("Television")
ticks.append("Music")
ticks.append("Books")
ticks.append("Magazines")
ticks.append("Newspapers")
ticks.append("Radio")
ticks.append("Gaming")
ticks.append("Internet")



# data to plot
n_groups = len(new_label)
val_2009 = []
val_2010 = []
val_2011 = []
for label in new_label:
    val_2009.append(entertainment_2009[label])
    val_2010.append(entertainment_2010[label])
    val_2011.append(entertainment_2011[label])
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Value (Lower is more valuable)')
plt.xlabel('Entertainment Options')
plt.title('Value of Entertainment by year')
plt.xticks(index + (bar_width), ticks, rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# ##### Top Entertainment Options
# * Television
# * Internet
# * Music

# %% [markdown]
# ## Internet Speed

# %%
label = "Internet Speed"
speed_2009 = dict(collections.Counter(df1[label]))
speed_2010 = dict(collections.Counter(df2[label]))
speed_2011 = dict(collections.Counter(df3[label]))

del speed_2009[nan]
del speed_2010[nan]
del speed_2011[nan]

# %%
want_speed_2009 = {}
money_2009 = {}
want_speed_2010 = {}
money_2010 = {}
want_speed_2011 = {}
money_2011 = {}

# %%
for key in speed_2009.keys():
    if key == 'I am not willing to pay more for faster download speeds as my current speed is sufficient for my needs' :
        want_speed_2009['No'] = speed_2009[key]
    else:
        if 'Yes' in want_speed_2009:
            want_speed_2009['Yes'] += speed_2009[key]
        else:
            want_speed_2009['Yes'] = speed_2009[key]
        if key == "I am willing to pay $5 per month on top of what I already pay":
            money_2009['$5'] = speed_2009[key]
        elif key == "I am willing to pay $10 per month on top of what I already pay":
            money_2009['$10'] = speed_2009[key]
        elif key == "I am willing to pay $20 per month on top of what I already pay":
            money_2009['$20'] = speed_2009[key]
        elif key == "I am willing to pay $30 or more per month on top of what I already pay":
            money_2009['$30'] = speed_2009[key]
        else:
            money_2009['Nothing extra'] = speed_2009[key]

for key in speed_2010.keys():
    if key == 'I am not willing to pay more for faster download speeds as my current speed is sufficient for my needs' :
        want_speed_2010['No'] = speed_2010[key]
    else:
        if 'Yes' in want_speed_2010:
            want_speed_2010['Yes'] += speed_2010[key]
        else:
            want_speed_2010['Yes'] = speed_2010[key]
        if key == "I am willing to pay $5 per month on top of what I already pay":
            money_2010['$5'] = speed_2010[key]
        elif key == "I am willing to pay $10 per month on top of what I already pay":
            money_2010['$10'] = speed_2010[key]
        elif key == "I am willing to pay $20 per month on top of what I already pay":
            money_2010['$20'] = speed_2010[key]
        elif key == "I am willing to pay $30 or more per month on top of what I already pay":
            money_2010['$30'] = speed_2010[key]
        else:
            money_2010['Nothing extra'] = speed_2010[key]

for key in speed_2011.keys():
    if key == 'I am not willing to pay more for faster download speeds as my current speed is sufficient for my needs' :
        want_speed_2011['No'] = speed_2011[key]
    else:
        if 'Yes' in want_speed_2011:
            want_speed_2011['Yes'] += speed_2011[key]
        else:
            want_speed_2011['Yes'] = speed_2011[key]
        if key == "I am willing to pay $5 per month on top of what I already pay":
            money_2011['$5'] = speed_2011[key]
        elif key == "I am willing to pay $10 per month on top of what I already pay":
            money_2011['$10'] = speed_2011[key]
        elif key == "I am willing to pay $20 per month on top of what I already pay":
            money_2011['$20'] = speed_2011[key]
        elif key == "I am willing to pay $30 or more per month on top of what I already pay":
            money_2011['$30'] = speed_2011[key]
        else:
            money_2011['Nothing extra'] = speed_2011[key]

# %%
ticks = []

ticks.append("Yes")




# data to plot
n_groups = len(ticks)
val_2009 = []
val_2010 = []
val_2011 = []
for label in ticks:
    val_2009.append(want_speed_2009[label])
    val_2010.append(want_speed_2010[label])
    val_2011.append(want_speed_2011[label])
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Need for internet')

plt.title('Need for internet speed by year')
plt.xticks(index + (bar_width), ticks)
plt.legend()
 

plt.show()

# %% [markdown]
# ### The need for faster internet is decreasing over time

# %% [markdown]
# ### How much would you pay for faster internet

# %%
# data to plot
n_groups = len(money_2009.keys())

val_2009 = money_2009.values()
val_2010 = money_2010.values()
val_2011 = money_2011.values()

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Number of people')
plt.xlabel('How much would you pay')
plt.title('Monetary input for internet speed by year')
plt.xticks(index + (bar_width), money_2009.keys())
plt.legend()
 

plt.show()

# %% [markdown]
# ###### As we can see across years, most people wanted faster internet at no additional cost, However people are willing to pay 5 or 10 dollars more for that. This coupled with the previous graph shows that people are getting faster internet each year and thus dont want to pay anything extra.

# %% [markdown]
# ## Using other's login

# %%
label = "Login Detail"
login_2009 = dict(collections.Counter(df1[label]))
login_2010 = dict(collections.Counter(df2[label]))
login_2011 = dict(collections.Counter(df3[label]))

# %%
ticks = []

ticks.append("Occasionally")
ticks.append("Never")
ticks.append("Frequently")
ticks.append("Rarely")
# data to plot
n_groups = len(ticks)
val_2009 = []
val_2010 = []
val_2011 = []
for label in login_2009.keys():
    val_2009.append(login_2009[label])
    val_2010.append(login_2010[label])
    val_2011.append(login_2011[label])
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Number of people')
plt.xlabel('Using someone else login details for streaming')

plt.xticks(index + (bar_width), ticks)
plt.legend()
 

plt.show()

# %% [markdown]
# #### A growing trend can be observed in the number of people who are using someone else's login information for online video streaming

# %% [markdown]
# ## Activities people do while watching TV

# %%
new_label = []
new_label.append("While TV - Read for work")
new_label.append("While TV - Read for pleasure")
new_label.append("While TV - Browse and surf the Web")
new_label.append("While TV - Microblogging")
new_label.append("While TV - Read email")
new_label.append("While TV - Write email")
new_label.append("While TV - Text message")
new_label.append("While TV - Use a social network")
new_label.append("While TV - Talk on the phone")
new_label.append("While TV - Browse for products and services online")
new_label.append("While TV - Purchase products and services online")
new_label.append("While TV - Play video games")

# %%
d = {}
d["Almost never"] = 0
d["Rarely (10%-50% of the time)"] = 1
d["Frequently (between 50% and 75% of the time)"] = 2
d["Almost always (greater than 75% of the time)"] = 3
d["Always (close to 100% of the time)"] = 4

# %%
for label in new_label:
    df1[label] = df1[label].map(d)
    df2[label] = df2[label].map(d)
    df3[label] = df3[label].map(d)

# %%
df1_graph = df1.dropna(subset=new_label, how='all', inplace = False)
df2_graph = df2.dropna(subset=new_label, how='all', inplace = False)
df3_graph = df3.dropna(subset=new_label, how='all', inplace = False)

# %%
while_tv_2009= {}
while_tv_2010= {}
while_tv_2011= {}
for label in new_label:
    while_tv_2009[label] = df1_graph[label].sum()
    while_tv_2010[label] = df2_graph[label].sum()
    while_tv_2011[label] = df3_graph[label].sum()

# %%
ticks = []
ticks.append("Browse and surf the Web")
ticks.append("Browse for products and services online")
ticks.append("Purchase products and services online")
ticks.append("Read for work")
ticks.append("Text message")
ticks.append("Read email")
ticks.append("Talk on the phone")
ticks.append("Read for pleasure")
ticks.append("Write email")
ticks.append("Use a social network")
ticks.append("Play video games")
ticks.append("Microblogging")

# %%
matplotlib.rc("figure", figsize=(15,6))
matplotlib.rc("axes", labelsize=16, titlesize=16)
matplotlib.rc("xtick", labelsize=14)
matplotlib.rc("ytick", labelsize=14)
matplotlib.rc("legend", fontsize=14)
matplotlib.rc("font", size=14)

# %%
n_groups = len(ticks)
val_2009 = []
val_2010 = []
val_2011 = []
for label in while_tv_2009.keys():
    val_2009.append(while_tv_2009[label])
    val_2010.append(while_tv_2010[label])
    val_2011.append(while_tv_2011[label])
 
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

rects1 = plt.bar(index, val_2009, bar_width,
                 alpha=opacity,
                 label='2009')

rects2 = plt.bar(index+ bar_width, val_2010, bar_width,
                 alpha=opacity,
                 label='2010')

rects3 = plt.bar(index+ (2*bar_width), val_2011, bar_width,
                 alpha=opacity,
                 label='2011')
 
 
plt.ylabel('Frequency of Activity')
plt.xlabel('Activity while watching Television')

plt.xticks(index + (bar_width), ticks, rotation = 90)
plt.legend()
 

plt.show()

# %% [markdown]
# #### As we can see the top activities people do while watching tv are :
# * Surfing the Web
# * Using Social Network
# * Reading Emails / Text Messages
